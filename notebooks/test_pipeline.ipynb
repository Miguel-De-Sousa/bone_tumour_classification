# %%
from ultralytics import YOLO
import os

# %%
test_folder = os.listdir('/Users/miguel/GitHub/bone_tumour_classification/test_images')

# %%
model = YOLO('/Users/miguel/GitHub/bone_tumour_classification/models/best.pt')

for img in test_folder:
    results = model(f'/Users/miguel/GitHub/bone_tumour_classification/test_images/{img}', save=True)
guess = results[0].verbose().strip()
print(guess)
# Out:
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image1.png: 1024x416 1 osteosarcoma, 76.9ms
# Speed: 2.1ms preprocess, 76.9ms inference, 4.4ms postprocess per image at shape (1, 3, 1024, 416)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict-2
#
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image2.png: 1024x768 1 giant cell tumor, 126.9ms
# Speed: 2.5ms preprocess, 126.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 768)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict-2
#
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image3.png: 1024x1024 2 multiple osteochondromass, 166.8ms
# Speed: 2.4ms preprocess, 166.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict-2
#
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image4.png: 1024x1024 1 simple bone cyst, 155.1ms
# Speed: 2.2ms preprocess, 155.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict-2
# 1 simple bone cyst,

# %%
model.export(format='onnx', dynamic=True, simplify=True)
# Out:
# Ultralytics 8.4.54 🚀 Python-3.14.5 torch-2.12.0 CPU (Apple M4)
#
# PyTorch: starting from '/Users/miguel/GitHub/bone_tumour_classification/models/best.pt' with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 13, 21504) (21.5 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Collecting onnx<2.0.0,>=1.12.0
#   Downloading onnx-1.21.0-cp312-abi3-macosx_12_0_universal2.whl.metadata (8.5 kB)
# Collecting onnxslim>=0.1.71
#   Downloading onnxslim-0.1.94-py3-none-any.whl.metadata (10 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.26.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.23.2 in /Users/miguel/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages (from onnx<2.0.0,>=1.12.0) (2.4.6)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/miguel/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages (from onnx<2.0.0,>=1.12.0) (7.35.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/miguel/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages (from onnx<2.0.0,>=1.12.0) (4.15.0)
# Collecting ml_dtypes>=0.5.0 (from onnx<2.0.0,>=1.12.0)
#   Downloading ml_dtypes-0.5.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Collecting colorama (from onnxslim>=0.1.71)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: packaging in /Users/miguel/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages (from onnxslim>=0.1.71) (26.2)
# Requirement already satisfied: sympy>=1.13.1 in /Users/miguel/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages (from onnxslim>=0.1.71) (1.14.0)
# Collecting flatbuffers (from onnxruntime)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/miguel/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages (from sympy>=1.13.1->onnxslim>=0.1.71) (1.3.0)
# Downloading onnx-1.21.0-cp312-abi3-macosx_12_0_universal2.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.0 MB ? eta -:--:--
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/18.0 MB 19.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/18.0 MB 19.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 10.5/18.0 MB 18.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 15.7/18.0 MB 20.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 17.3/18.0 MB 17.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 18.1 MB/s  0:00:01
# Downloading onnxslim-0.1.94-py3-none-any.whl (238 kB)
# Downloading onnxruntime-1.26.0-cp314-cp314-macosx_14_0_arm64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.0 MB ? eta -:--:--
#    ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/18.0 MB 29.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━ 8.9/18.0 MB 22.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 13.4/18.0 MB 22.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 15.7/18.0 MB 19.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 20.3 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp314-cp314-macosx_10_13_universal2.whl (673 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/673.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 673.8/673.8 kB 29.9 MB/s  0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Installing collected packages: flatbuffers, onnxruntime, ml_dtypes, colorama, onnx, onnxslim
#
#    ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [onnxruntime]
#    ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 5/6 [onnxslim]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [onnxslim]
#
# Successfully installed colorama-0.4.6 flatbuffers-25.12.19 ml_dtypes-0.5.4 onnx-1.21.0 onnxruntime-1.26.0 onnxslim-0.1.94
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
#
# requirements: AutoUpdate success ✅ 5.4s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 7.4s, saved as '/Users/miguel/GitHub/bone_tumour_classification/models/best.onnx' (42.9 MB)
#
# Export complete (7.8s)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/models/best.onnx
# Predict:         yolo predict task=detect model=/Users/miguel/GitHub/bone_tumour_classification/models/best.onnx imgsz=1024
# Validate:        yolo val task=detect model=/Users/miguel/GitHub/bone_tumour_classification/models/best.onnx imgsz=1024 data=/kaggle/input/datasets/migueladesousa/bone-tumour-classification/data.yaml
# Visualize:       https://netron.app
# '/Users/miguel/GitHub/bone_tumour_classification/models/best.onnx'
