# %%
from ultralytics import YOLO
import os

# %%
test_folder = os.listdir('test_images')

# %%
model = YOLO('models/best.pt')

for img in test_folder:
    results = model(f'test_images/{img}', save=True)
guess = results[0].verbose().strip()
print(guess)
# Out:
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image1.png: 1024x416 1 osteosarcoma, 72.9ms
# Speed: 1.1ms preprocess, 72.9ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 416)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict
#
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image2.png: 1024x768 1 giant cell tumor, 153.0ms
# Speed: 1.7ms preprocess, 153.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 768)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict
#
# image 1/1 /Users/miguel/GitHub/bone_tumour_classification/test_images/test_image3.png: 1024x1024 2 multiple osteochondromass, 175.9ms
# Speed: 2.3ms preprocess, 175.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /Users/miguel/GitHub/bone_tumour_classification/runs/detect/predict
#
# ...
