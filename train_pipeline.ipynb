# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in ./bone_venv/lib/python3.14/site-packages (8.4.54)
# Requirement already satisfied: numpy>=1.23.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (2.4.6)
# Requirement already satisfied: matplotlib>=3.3.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: scipy>=1.4.1 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (2.12.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (0.27.0)
# Requirement already satisfied: psutil>=5.8.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (1.41.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in ./bone_venv/lib/python3.14/site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./bone_venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.41.0 in ./bone_venv/lib/python3.14/site-packages (from polars>=0.20.0->ultralytics) (1.41.0)
# Requirement already satisfied: six>=1.5 in ./bone_venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./bone_venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./bone_venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in ./bone_venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./bone_venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./bone_venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./bone_venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./bone_venv/lib/python3.14/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO('yolov8s.pt')

results = model.train(data='data.yaml', 
                      epochs=100, imgsz=1024, 
                      batch=8,
                      device=0,
                      project='/kaggle/working/runs')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 23.7MB/s 0.9s 0.9s<0.0s
# New https://pypi.org/project/ultralytics/8.4.56 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.54 🚀 Python-3.14.5 torch-2.12.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 from ultralytics import YOLO
#       2 model = YOLO('yolov8s.pt')
#       3
# ----> 4 results = model.train(data='data.yaml',
#       5                       epochs=100, imgsz=1024,
#       6                       batch=8,
#       7                       device=0,
#
# File ~/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages/ultralytics/engine/model.py:783, in Model.train(self, trainer, **kwargs)
#     776             LOGGER.warning(
#     777                 f"model '{self.ckpt_path}' is not a resumable training checkpoint "
#     778                 f"(missing epoch/optimizer state). Use 'resume' only to continue incomplete training. "
#     779                 f"Starting new training instead."
#     780             )
#     781             args["resume"] = False
# --> 783 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     784 if not args.get("resume") and self.ckpt:
#     785     # Reuse the already-loaded checkpoint model to avoid re-resolving remote weight sources during trainer setup.
#     786     weights = None if pretrained is False else self.model
#
# File ~/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages/ultralytics/models/yolo/detect/train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks: dict | None = None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection models.
#      57
#      58     Args:
#    (...)     61         _callbacks (dict, optional): Dictionary of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File ~/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages/ultralytics/engine/trainer.py:128, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     126 self.args = get_cfg(cfg, overrides)
#     127 self.check_resume(overrides)
# --> 128 self.device = select_device(self.args.device)
#     129 # Update "-1" devices so post-training val does not repeat search
#     130 self.args.device = os.getenv("CUDA_VISIBLE_DEVICES") if "cuda" in str(self.device) else str(self.device)
#
# File ~/GitHub/bone_tumour_classification/bone_venv/lib/python3.14/site-packages/ultralytics/utils/torch_utils.py:231, in select_device(device, newline, verbose)
#     224         LOGGER.info(s)
#     225         install = (
#     226             "See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no "
#     227             "CUDA devices are seen by torch.\n"
#     228             if torch.cuda.device_count() == 0
#     229             else ""
#     230         )
# --> 231         raise ValueError(
#     232             f"Invalid CUDA 'device={device}' requested."
#     233             f" Use 'device=cpu' or pass valid CUDA device(s) if available,"
#     234             f" i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.\n"
#     235             f"\ntorch.cuda.is_available(): {torch.cuda.is_available()}"
#     236             f"\ntorch.cuda.device_count(): {torch.cuda.device_count()}"
#     237             f"\nos.environ['CUDA_VISIBLE_DEVICES']: {visible}\n"
#     238             f"{install}"
#     239         )
#     241 if not cpu and not mps and torch.cuda.is_available():  # prefer GPU if available
#     242     devices = device.split(",") if device else "0"  # i.e. "0,1" -> ["0", "1"]
#
# ValueError: Invalid CUDA 'device=0' requested. Use 'device=cpu' or pass valid CUDA device(s) if available, i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.
#
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
# os.environ['CUDA_VISIBLE_DEVICES']: None
# See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no CUDA devices are seen by torch.
